# %% [markdown]
# ### 1. Importação de Bibliotecas
# Realize a importação da biblioteca pandas.

# %%
### importando a biblioteca pandas
import pandas as pd

# %% [markdown]
# ### 2. Importação da Base de Dados
#
# Importe o arquivo 'Tabela_Clubes.csv' o transforme em um dataframe e mostre as informações.

# %%
### carregando o arquivo CSV em um DataFrame
df =  pd.read_csv('Tabela_Clubes.csv')
### mostrando as informações gerais do DataFrame
df
# Out:
#       Ano  Pos.        Clubes  Vitorias  Derrotas  Empates GolsF/S  Saldo  \
# 0    2017    18    America-MG        10        10       18   30:47    -17
# 1    2017     7  Athletico-PR        16         9       13   54:37     17
# 2    2017     6   Atletico-MG        17         8       13   56:43     13
# 3    2017    11         Bahia        12        12       14   39:41     -2
# 4    2017     9      Botafogo        13        12       13   38:46     -8
# ..    ...   ...           ...       ...       ...      ...     ...    ...
# 195  2008    18   Santo Andre        11         8       19   46:61    -15
# 196  2008    12        Santos        12        13       13   58:58      0
# 197  2008     3     Sao Paulo        18        11        9   57:42     15
# 198  2008    20         Sport         7        10       21   48:71    -23
# 199  2008    13       Vitoria        13         9       16   51:57     -6
#
#      Qtd_Jogadores Idade_Media  Estrangeiros  Valor_total  Media_Valor  \
# 0               51        24,8             0     27350000       536000
# 1               52          24             3     37650000       724000
# 2               50        23,4             6     61350000      1230000
# 3               48        23,2             2     34900000       727000
# 4               45        23,1             4     25550000       568000
# ..             ...         ...           ...          ...          ...
# 195             43        25,1             3      6230000       145000
# 196             33        23,9             1     27850000       844000
# 197             30        23,9             1     46650000      1560000
# 198             30          25             1     15600000       520000
# 199             38        24,1             2     13450000       354000
#
#      Unnamed: 13  Unnamed: 14 Unnamed: 15  Unnamed: 16
# 0            NaN          NaN         NaN          NaN
# 1            NaN          NaN         NaN          NaN
# 2            NaN          NaN         NaN          NaN
# 3            NaN          NaN         NaN          NaN
# 4            NaN          NaN         NaN          NaN
# ..           ...          ...         ...          ...
# 195          NaN          NaN         NaN          NaN
# 196          NaN          NaN         NaN          NaN
# 197          NaN          NaN         NaN          NaN
# 198          NaN          NaN         NaN          NaN
# 199          NaN          NaN         NaN          NaN
#
# [200 rows x 17 columns]

# %% [markdown]
# ### 3. Mostre as primeiras linhas do DataFrame

# %%
### mostrando as primeiras linhas do DataFrame
df.head(5)
# Out:
#     Ano  Pos.        Clubes  Vitorias  Derrotas  Empates GolsF/S  Saldo  \
# 0  2017    18    America-MG        10        10       18   30:47    -17
# 1  2017     7  Athletico-PR        16         9       13   54:37     17
# 2  2017     6   Atletico-MG        17         8       13   56:43     13
# 3  2017    11         Bahia        12        12       14   39:41     -2
# 4  2017     9      Botafogo        13        12       13   38:46     -8
#
#    Qtd_Jogadores Idade_Media  Estrangeiros  Valor_total  Media_Valor  \
# 0             51        24,8             0     27350000       536000
# 1             52          24             3     37650000       724000
# 2             50        23,4             6     61350000      1230000
# 3             48        23,2             2     34900000       727000
# 4             45        23,1             4     25550000       568000
#
#    Unnamed: 13  Unnamed: 14 Unnamed: 15  Unnamed: 16
# 0          NaN          NaN         NaN          NaN
# 1          NaN          NaN         NaN          NaN
# 2          NaN          NaN         NaN          NaN
# 3          NaN          NaN         NaN          NaN
# 4          NaN          NaN         NaN          NaN

# %% [markdown]
# ### 4. Removendo Colunas sem informações.

# %%
### Se observamos bem, podemos ver que temos quatro colounas sem nome e sem informações, ou seja valores nulos
### removendo as colunas sem nome
df = df.drop(columns=['Unnamed: 13', 'Unnamed: 14', 'Unnamed: 15', 'Unnamed: 16'])
### mostrando as informações gerais do DataFrame após a remoção das colunas
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 200 entries, 0 to 199
# Data columns (total 13 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   Ano            200 non-null    int64
#  1   Pos.           200 non-null    int64
#  2   Clubes         200 non-null    object
#  3   Vitorias       200 non-null    int64
#  4   Derrotas       200 non-null    int64
#  5   Empates        200 non-null    int64
#  6   GolsF/S        200 non-null    object
#  7   Saldo          200 non-null    int64
#  8   Qtd_Jogadores  200 non-null    int64
#  9   Idade_Media    200 non-null    object
#  10  Estrangeiros   200 non-null    int64
#  11  Valor_total    200 non-null    int64
#  12  Media_Valor    200 non-null    int64
# dtypes: int64(10), object(3)
# memory usage: 20.4+ KB

# %% [markdown]
# ### 5. Quais os times aparecem na tabela e quantas vezes cada um aparece?

# %%
### vamos ver quais os times aparecem na tabela e quantas vezes cada um aparece
df["Clubes"].value_counts()
# Out:
# Clubes
# Flamengo         10
# Atletico-MG      10
# Santos           10
# Sao Paulo        10
# Cruzeiro         10
# Corinthians      10
# Gremio           10
# Fluminense       10
# Palmeiras         9
# Athletico-PR      9
# Botafogo          9
# Internacional     9
# Coritiba          8
# Vasco             7
# Sport             7
# Vitoria           7
# Bahia             6
# Figueirense       5
# Goias             5
# Ponte Preta       5
# Chapecoense       5
# Avai              5
# Atletico-GO       4
# America-MG        3
# Nautico           3
# Ceara             3
# Criciuma          2
# Prudente          2
# Portuguesa        2
# Parana            1
# Santa Cruz        1
# Joinville         1
# Guarani           1
# Santo Andre       1
# Name: count, dtype: int64

# %% [markdown]
# ### 6. Quantos times diferentes temos no DataFrame?

# %%
### vamos contar o total de times únicos na tabela
len(df["Clubes"].unique())
# Out:
# 34

# %%
df["Clubes"].nunique()
# Out:
# 34

# %% [markdown]
# ### 7. Quais os anos que aparecem no DataFrame?

# %%
### vamos ver quais anos aparecem na tabela
print(df["Ano"].unique())
### vamos ordenar os anos de forma crescente
df["Ano"].sort_values().unique()
# Out:
# [2017 2016 2015 2014 2013 2012 2011 2010 2009 2008]
# array([2008, 2009, 2010, 2011, 2012, 2013, 2014, 2015, 2016, 2017])

# %% [markdown]
# ### 8. Quais os campeões de cada ano?

# %%
### vamos verificar os campeões de cada ano e ordenar por ano
df[df["Pos."] == 1][["Clubes", "Ano"]].sort_values(by="Ano")
# Out:
#           Clubes   Ano
# 187     Flamengo  2008
# 169   Fluminense  2009
# 148  Corinthians  2010
# 129   Fluminense  2011
# 107     Cruzeiro  2012
# 88      Cruzeiro  2013
# 64   Corinthians  2014
# 53     Palmeiras  2015
# 27   Corinthians  2016
# 13     Palmeiras  2017

# %% [markdown]
# ### 9. Qual o time que foi mais vezes campeão?

# %%
### qual time apareceu mais vezes como campeão?
df[df["Pos."] == 1]["Clubes"].value_counts().idxmax()
# Out:
# 'Corinthians'

# %% [markdown]
# ### 10. Agora uma piada 😄, quais times paulistas não aparecem nenhuma vez como campeão?
#
# Responda com um print

# %%
### seu código aqui

# %% [markdown]
# ### 11. Qual o time com mais derrotas?

# %%
### qual o time com mais derrotas?
max_derrotas = df['Derrotas'].max()
df[df['Derrotas'] == max_derrotas]
### mostrando todas as informações do time com mais derrotas
# Out:
#       Ano  Pos.       Clubes  Vitorias  Derrotas  Empates GolsF/S  Saldo  \
# 104  2012    10  Corinthians        11        17       10   27:22      5
# 156  2010    11    Palmeiras        11        17       10   43:39      4
# 164  2009     6     Botafogo        14        17        7   54:42     12
# 165  2009    12        Ceara        10        17       11   35:44     -9
# 168  2009    14     Flamengo         9        17       12   41:44     -3
#
#      Qtd_Jogadores Idade_Media  Estrangeiros  Valor_total  Media_Valor
# 104             57        22,7             3     36000000       632000
# 156             46        23,6             2     55250000      1200000
# 164             55        23,3             3     27150000       494000
# 165             43        25,8             0     10650000       248000
# 168             46        23,8             5     72900000      1580000

# %% [markdown]
# ### 12. Qual o time com menos derrotas?

# %%
### qual o time com menos derrotas?
min_derrotas = df['Derrotas'].min()
df[df['Derrotas'] == min_derrotas]

### mostrando todas as informações do time com menos derrotas
# Out:
#       Ano  Pos.      Clubes  Vitorias  Derrotas  Empates GolsF/S  Saldo  \
# 153  2010     3  Fluminense        20         3       15   60:51      9
#
#      Qtd_Jogadores Idade_Media  Estrangeiros  Valor_total  Media_Valor
# 153             51        23,9             6     60650000      1190000

# %% [markdown]
# ### 13. Qual o time com maior número de estrangeiros?

# %%
### qual o time com maior número de estrangeiros?
max_estrangeiros = df['Estrangeiros'].max()
df[df['Estrangeiros'] == max_estrangeiros]

### mostrando todas as informações do time com mais estrangeiros
# Out:
#      Ano  Pos.    Clubes  Vitorias  Derrotas  Empates GolsF/S  Saldo  \
# 68  2014    12  Flamengo        15         4       19   45:53     -8
#
#     Qtd_Jogadores Idade_Media  Estrangeiros  Valor_total  Media_Valor
# 68             36        24,3             8     34450000       957000

# %% [markdown]
# ### 14. qual o time com o menor número de estrangeiros?

# %%
### qual o time com menor número de estrangeiros?
min_estrangeiros = df['Estrangeiros'].min()
df[df['Estrangeiros'] == min_estrangeiros]
# Out:
#       Ano  Pos.       Clubes  Vitorias  Derrotas  Empates GolsF/S  Saldo  \
# 0    2017    18   America-MG        10        10       18   30:47    -17
# 21   2016    20  Atletico-GO         9         9       20   38:56    -18
# 44   2015    11  Chapecoense        13        13       11   49:53     -4
# 50   2015    13   Fluminense        13        11       14   45:45      0
# 54   2015     9  Ponte Preta        15         8       15   48:52     -4
# 59   2015    16      Vitoria        12         9       17   51:53     -2
# 63   2014    14  Chapecoense        12        11       15   34:44    -10
# 70   2014    19        Goias        10         8       20   39:49    -10
# 75   2014    11  Ponte Preta        13        12       13   41:40      1
# 78   2014     6        Sport        15        14        9   53:38     15
# 84   2013    15  Chapecoense        11        10       17   39:44     -5
# 89   2013    13  Figueirense        13         8       17   37:47    -10
# 92   2013    12        Goias        13         8       17   38:40     -2
# 111  2012     2       Gremio        18        11        9   42:35      7
# 120  2011    19  Atletico-GO         7         9       22   37:67    -30
# 122  2011    15        Bahia        11        14       13   37:41     -4
# 134  2011    14  Ponte Preta        12        12       14   37:44     -7
# 135  2011    16   Portuguesa        10        15       13   39:41     -2
# 140  2010    19   America-MG         8        13       17   51:69    -18
# 142  2010    13  Atletico-GO        12        12       14   50:45      5
# 147  2010    18        Ceara        10         9       19   47:64    -17
# 161  2009    16  Atletico-GO        11         9       18   51:57     -6
# 163  2009    15         Avai        11        10       17   49:58     -9
# 165  2009    12        Ceara        10        17       11   35:44     -9
# 170  2009    19        Goias         8         9       21   41:68    -27
# 172  2009    18      Guarani         8        13       17   33:53    -20
# 175  2009    20     Prudente         7        10       21   39:64    -25
# 181  2008     7  Atletico-MG        16         8       14   55:56     -1
# 182  2008     6         Avai        15        12       11   61:52      9
# 189  2008     9        Goias        15        10       13   64:65     -1
#
#      Qtd_Jogadores Idade_Media  Estrangeiros  Valor_total  Media_Valor
# 0               51        24,8             0     27350000       536000
# 21              43        23,5             0     14900000       347000
# 44              51        26,3             0     35200000       690000
# 50              30        24,7             0     53850000      1800000
# 54              43        24,7             0     28150000       655000
# 59              30        23,2             0     23450000       782000
# 63              36        26,5             0      6750000       188000
# 70              56          23             0      7250000       129000
# 75              42        23,3             0      7700000       183000
# 78              46        23,6             0     20850000       453000
# 84              30        25,8             0      4400000       147000
# 89              28        24,5             0      4900000       175000
# 92              23        23,5             0      4250000       185000
# 111             38        24,1             0      8650000       228000
# 120             44        24,6             0     13850000       315000
# 122             44        23,5             0     18300000       416000
# 134             50        24,5             0     12500000       250000
# 135             41        25,2             0      9100000       222000
# 140             43        24,7             0      5950000       138000
# 142             43        24,3             0     15600000       363000
# 147             50        25,7             0     25000000       500000
# 161             36        24,6             0      7800000       217000
# 163             42        22,7             0      9650000       230000
# 165             43        25,8             0     10650000       248000
# 170             47        25,6             0     28250000       601000
# 172             36        24,6             0      8750000       243000
# 175             32          23             0      7950000       248000
# 181             32        23,5             0     16850000       527000
# 182             36        23,3             0      3450000        96000
# 189             36        23,7             0     12600000       350000

# %% [markdown]
# ### 15. Bônus
#
# Vamos criar um gráfico que mostre os maiores campeões presentes nessa base de dados

# %%
import matplotlib.pyplot as plt

# Vamos criar um gráfico de barras para visualizar os times com mais títulos
titulos = df['Clubes'].value_counts()

plt.figure(figsize=(14, 8))
bars = plt.bar(titulos.index, titulos.values,
               color=['#1f77b4', '#ff7f0e', '#2ca02c', '#d62728', '#9467bd',
                      '#8c564b', '#e377c2', '#7f7f7f', '#bcbd22', '#17becf'],
               edgecolor='black', linewidth=0.5, alpha=0.8)

# Adicionar os valores em cima de cada barra
for bar in bars:
    height = bar.get_height()
    plt.text(bar.get_x() + bar.get_width()/2., height + 0.05,
             f'{int(height)}', ha='center', va='bottom', fontsize=10, fontweight='bold')

plt.title('Times com Mais Títulos', fontsize=16, fontweight='bold', pad=20)
plt.xlabel('Clubes', fontsize=12, fontweight='bold')
plt.ylabel('Número de Títulos', fontsize=12, fontweight='bold')

# Ajustar a escala do eixo Y de 0 a 3
plt.ylim(0, 3)

# Melhorar a aparência dos eixos
plt.xticks(rotation=0, ha='right')
plt.yticks(range(0, 4))  # Apenas números inteiros de 0 a 3

# Adicionar grid para melhor leitura
plt.grid(axis='y', alpha=0.3, linestyle='--')

# Ajustar layout para evitar cortes
plt.tight_layout()

# Mostrar o gráfico
plt.show()
# Out:
# /tmp/ipython-input-3918403413.py:33: UserWarning: Tight layout not applied. The bottom and top margins cannot be made large enough to accommodate all Axes decorations.
#   plt.tight_layout()
